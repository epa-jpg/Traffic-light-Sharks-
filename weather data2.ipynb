# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
weather_data = pd.read_csv("C:/Users/Asus/Desktop/The-Data-Series-master/The-Data-Series-master/Episode 4.3/weatherdata.csv")

# %%
weather_data.describe()
# Out:
#        Temperature(C)   Humidity
# count       50.000000  50.000000
# mean        13.409111   0.661400
# std          4.408296   0.164565
# min          6.111111   0.360000
# 25%          9.572222   0.532500
# 50%         13.527778   0.665000
# 75%         17.286111   0.815000
# max         21.183333   0.950000

# %%
weather_data.head()
# Out:
#    Temperature(C)  Humidity
# 0        9.472222      0.89
# 1        9.355556      0.86
# 2        9.377778      0.89
# 3        8.288889      0.83
# 4        8.755556      0.83

# %%
weather_data.tail()
# Out:
#     Temperature(C)  Humidity
# 45       15.022222      0.55
# 46       14.422222      0.58
# 47       14.255556      0.59
# 48       13.772222      0.60
# 49       13.283333      0.63

# %%
weather_data.corr()
# Out:
#                 Temperature(C)  Humidity
# Temperature(C)        1.000000 -0.943471
# Humidity             -0.943471  1.000000

# %%
import seaborn as sns #
sns.heatmap(weather_data.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
x = weather_data["Temperature(C)"]
y= weather_data["Humidity"]

# %%
plt.scatter(x,y)
plt.xlabel("Temperature")
plt.ylabel("Humidity")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
x = weather_data["Temperature(C)"].values.reshape(-1,1)
y = weather_data["Humidity"]

shexa_model = LinearRegression()

# %%
shexa_model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = shexa_model.predict(x)
#pint(y_pred)

# %%
plt.scatter(x,y)
plt.xlabel('Temperature(C)')
plt.ylabel('Humidity')

plt.plot(x,y_pred)
