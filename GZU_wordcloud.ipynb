# %% [markdown]
# <a href="https://colab.research.google.com/github/epa-jpg/Traffic-light-Sharks-/blob/main/GZU_wordcloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mount your google drive for access to dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Untitled folder
# Out:
# /content/drive/MyDrive/Untitled folder

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(' sentiment_reviews - sentiment_reviews.csv')

# %% [markdown]
# **Change the directory**

# %%
data.describe()
# Out:
#                                                    review
# count                                                   5
# unique                                                  5
# top     This restaurant was fantastic! The food was gr...
# freq                                                    1

# %%
data.head()
# Out:
#                                               review
# 0  This restaurant was fantastic! The food was gr...
# 1  I had a terrible experience. The food was cold...
# 2            Average food but the ambiance was nice.
# 3  Best dining experience ever! Highly recommend ...
# 4  Not worth the price. The food was mediocre and...

# %%
data.tail()
# Out:
#                                               review
# 0  This restaurant was fantastic! The food was gr...
# 1  I had a terrible experience. The food was cold...
# 2            Average food but the ambiance was nice.
# 3  Best dining experience ever! Highly recommend ...
# 4  Not worth the price. The food was mediocre and...

# %% [markdown]
# **import necessary libraries**

# %% [markdown]
# Intialize your *dataset*

# %% [markdown]
# **Put all words into a single string**

# %% [markdown]
# **Generate a word cloud to visualise the reviews**

# %% [markdown]
# **Display the word cloud**
